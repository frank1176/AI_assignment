# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv('books.csv', low_memory=False)
books.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
ratings = pd.read_csv('ratings.csv', low_memory=False)
ratings.head()
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4

# %%
tags = pd.read_csv('tags.csv', low_memory=False)
tags.head()
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-
# 3       3    --12-
# 4       4   --122-

# %%
book_tags = pd.read_csv('book_tags.csv', low_memory=False)
book_tags.head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %%
to_read = pd.read_csv('to_read.csv', low_memory=False)
to_read.head()
# Out:
#    user_id  book_id
# 0        1      112
# 1        1      235
# 2        1      533
# 3        1     1198
# 4        1     1874

# %%
books.columns
# Out:
# Index(['id', 'book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'small_image_url'],
#       dtype='object')

# %%
ratings.columns
# Out:
# Index(['book_id', 'user_id', 'rating'], dtype='object')

# %%
tags.columns
# Out:
# Index(['tag_id', 'tag_name'], dtype='object')

# %%
book_tags.columns
# Out:
# Index(['goodreads_book_id', 'tag_id', 'count'], dtype='object')

# %%
to_read.columns
# Out:
# Index(['user_id', 'book_id'], dtype='object')

# %%
books.sort_values(by = ['ratings_count'], ascending = False).head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
books.sort_values(by = ['average_rating', 'ratings_count',
       'work_ratings_count'], ascending = False).head()
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 3627  3628     24812         24812     25599           14   740748475
# 861    862  17332218      17332218  16482835           34   765326361
# 3274  3275         8             8  21457576           11   439682584
# 8853  8854     95602         95602    920037            6   842339523
# 7946  7947   5031805       5031805  40769318           96  1433502410
#
#             isbn13                                     authors  \
# 3627  9.780741e+12                              Bill Watterson
# 861   9.780765e+12                           Brandon Sanderson
# 3274  9.780440e+12                 J.K. Rowling, Mary GrandPré
# 8853  9.780842e+12                             Francine Rivers
# 7946  9.781434e+12  Anonymous, Lane T. Dennis, Wayne A. Grudem
#
#       original_publication_year                  original_title  ...  \
# 3627                     2005.0  The Complete Calvin and Hobbes  ...
# 861                      2014.0               Words of Radiance  ...
# 3274                     2003.0                             NaN  ...
# 8853                     1993.0        Mark of the Lion Trilogy  ...
# 7946                     2002.0                             NaN  ...
#
#      ratings_count work_ratings_count  work_text_reviews_count  ratings_1  \
# 3627         28900              29968                      861        120
# 861          73572             108176                     7261        154
# 3274         33220              33424                      156        317
# 8853          9081               9547                      731         27
# 7946          8953              10784                      262         98
#
#       ratings_2  ratings_3  ratings_4  ratings_5  \
# 3627        154        693       3117      25884
# 861         404       2653      18272      86693
# 3274        233        978       3686      28210
# 8853         61        323       1363       7773
# 7946         90        367       1152       9077
#
#                                               image_url  \
# 3627  https://images.gr-assets.com/books/1473064526m...
# 861   https://images.gr-assets.com/books/1391535251m...
# 3274  https://s.gr-assets.com/assets/nophoto/book/11...
# 8853  https://images.gr-assets.com/books/1349032180m...
# 7946  https://images.gr-assets.com/books/1410151002m...
#
#                                         small_image_url
# 3627  https://images.gr-assets.com/books/1473064526s...
# 861   https://images.gr-assets.com/books/1391535251s...
# 3274  https://s.gr-assets.com/assets/nophoto/book/50...
# 8853  https://images.gr-assets.com/books/1349032180s...
# 7946  https://images.gr-assets.com/books/1410151002s...
#
# [5 rows x 23 columns]

# %%
df_book = books[['book_id','original_title', 'average_rating', 'ratings_count']]
df_book
# Out:
#       book_id                                     original_title  \
# 0     2767052                                   The Hunger Games
# 1           3           Harry Potter and the Philosopher's Stone
# 2       41865                                           Twilight
# 3        2657                              To Kill a Mockingbird
# 4        4671                                   The Great Gatsby
# ...       ...                                                ...
# 9995  7130616                                         Bayou Moon
# 9996   208324                                   Means of Ascent
# 9997    77431                              The Mauritius Command
# 9998  8565083  Cinderella Ate My Daughter: Dispatches from th...
# 9999     8914                                The First World War
#
#       average_rating  ratings_count
# 0               4.34        4780653
# 1               4.44        4602479
# 2               3.57        3866839
# 3               4.25        3198671
# 4               3.89        2683664
# ...              ...            ...
# 9995            4.09          17204
# 9996            4.25          12582
# 9997            4.35           9421
# 9998            3.65          11279
# 9999            4.00           9162
#
# [10000 rows x 4 columns]

# %%
df_book.describe()
# Out:
#             book_id  average_rating  ratings_count
# count  1.000000e+04    10000.000000   1.000000e+04
# mean   5.264697e+06        4.002191   5.400124e+04
# std    7.575462e+06        0.254427   1.573700e+05
# min    1.000000e+00        2.470000   2.716000e+03
# 25%    4.627575e+04        3.850000   1.356875e+04
# 50%    3.949655e+05        4.020000   2.115550e+04
# 75%    9.382225e+06        4.180000   4.105350e+04
# max    3.328864e+07        4.820000   4.780653e+06

# %%
C = df_book['average_rating'].mean()
C
# Out:
# 4.002191000000001

# %%
m = df_book['ratings_count'].quantile(0.90) 
m
# Out:
# 94103.10000000003

# %%
# Extract all qualified movies into a new DataFrame
q_books = df_book.copy().loc[df_book['ratings_count'] >= m]
q_books
# Out:
#        book_id                            original_title  average_rating  \
# 0      2767052                          The Hunger Games            4.34
# 1            3  Harry Potter and the Philosopher's Stone            4.44
# 2        41865                                  Twilight            3.57
# 3         2657                     To Kill a Mockingbird            4.25
# 4         4671                          The Great Gatsby            3.89
# ...        ...                                       ...             ...
# 1334     60510                              Poison Study            4.16
# 1335    304027                             Lover Unbound            4.33
# 1352  13206900                                    Winter            4.49
# 1396     37586                           The Lost Colony            4.01
# 1452  18692431                    Everything, Everything            4.11
#
#       ratings_count
# 0           4780653
# 1           4602479
# 2           3866839
# 3           3198671
# 4           2683664
# ...             ...
# 1334          96417
# 1335          97514
# 1352         100464
# 1396         103844
# 1452         132552
#
# [1000 rows x 4 columns]

# %%
len(q_books)
# Out:
# 1000

# %% [markdown]
# Weighted Rating
# v is the number of votes for the movie (represented by vote_count)
#
# m is the minimum of votes required to be listed in the chart (to be calculated)
#
# R is the average rating of the movie (represented by vote_average)
#
# C is the mean of average_rating across the whole report (to be calculated)
#
# (v / (v + m) * R) + (m / (m + v) * C)

# %%
def weighted_rating(x, m = m, C = C):
    
    v = x['ratings_count']
    R = x['average_rating']
    
    # Calculation based on the IMDB formula
    return (v / (v + m) * R) + (m / (m + v) * C)

# %%
q_books['score'] = q_books.apply(weighted_rating, axis=1)
q_books['score'].head()
# Out:
# 0    4.333479
# 1    4.431228
# 2    3.580268
# 3    4.242918
# 4    3.893801
# Name: score, dtype: float64

# %%
q_books.head()
# Out:
#    book_id                            original_title  average_rating  \
# 0  2767052                          The Hunger Games            4.34
# 1        3  Harry Potter and the Philosopher's Stone            4.44
# 2    41865                                  Twilight            3.57
# 3     2657                     To Kill a Mockingbird            4.25
# 4     4671                          The Great Gatsby            3.89
#
#    ratings_count     score
# 0        4780653  4.333479
# 1        4602479  4.431228
# 2        3866839  3.580268
# 3        3198671  4.242918
# 4        2683664  3.893801

# %% [markdown]
# # Recommander Top 20 Book

# %%
# Sort movies based on score calculated above
q_books = q_books.sort_values('score', ascending = False)
# Print the top 20 movies
q_books.head(20)
# Out:
#        book_id                             original_title  average_rating  \
# 24      136251       Harry Potter and the Deathly Hallows            4.61
# 26           1     Harry Potter and the Half-Blood Prince            4.54
# 17           5   Harry Potter and the Prisoner of Azkaban            4.53
# 23           6        Harry Potter and the Goblet of Fire            4.53
# 421     862041            Complete Harry Potter Boxed Set            4.74
# 134      62291                          A Storm of Swords            4.54
# 191     186074                       The Name of the Wind            4.55
# 20           2  Harry Potter and the Order of the Phoenix            4.46
# 1            3   Harry Potter and the Philosopher's Stone            4.44
# 160      18512                     The Return of the King            4.51
# 30     4667024                                   The Help            4.45
# 38       13496                          A Game of Thrones            4.45
# 306    1215032                        The Wise Man's Fear            4.57
# 174    4502507                          The Last Olympian            4.50
# 266   21853621                            The Nightingale            4.54
# 561    7235533                           The Way of Kings            4.64
# 1307  17927395                   A Court of Mist and Fury            4.72
# 188         33                      The Lord of the Rings            4.47
# 459   18335634                         Clockwork Princess            4.59
# 350   10025305                           Clockwork Prince            4.46
#
#       ratings_count     score
# 24          1746574  4.578926
# 26          1678823  4.511454
# 17          1832823  4.504224
# 23          1753043  4.503111
# 421          190050  4.495659
# 134          469022  4.450127
# 191          400101  4.445690
# 20          1735368  4.436452
# 1           4602479  4.431228
# 160          463959  4.424371
# 30          1531753  4.424081
# 38          1319204  4.420183
# 306          245686  4.412748
# 174          397500  4.404709
# 266          253606  4.394449
# 561          144822  4.388792
# 1307         108384  4.386408
# 188          389054  4.378886
# 459          162099  4.374098
# 350          307994  4.352859
